# %% [markdown]
# <a href="https://colab.research.google.com/github/AN2442/Flyrank_ML/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/AN2442/Flyrank_ML/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*
#
# **Lane:** Refresh / Content Opportunity Scoring
#
# **ML task type:** Scoring
#
# I frame this lane as a scoring problem because the goal is to assign each page a priority score based on observable page and performance signals. The scores can then be used to create a ranked list of pages for content review.
#
# The output is not an automatic refresh decision. Instead, it is a decision-support signal that helps the content/SEO team decide which pages to review first.
#
# **ML task framing:**
#
#  Given the available page-level signals, estimate a priority score for each page that can be used to rank pages for potential content review or refresh.
#
# The resulting ranking would support the action:
#
# Review the highest-priority pages first and determine through human judgment whether they actually need to be refreshed.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/AN2442/Flyrank_ML/main/data/raw/content_refresh_anonymized.csv")

print("Shape:", df.shape)
print("\nColumns:")
print(df.columns.tolist())
# Out:
# Shape: (30000, 44)
#
# Columns:
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count', 'char_count', 'provider_used', 'model_used', 'impressions_90d', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d', 'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d', 'days_with_impressions', 'days_with_sessions', 'impressions_last_30d', 'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d', 'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier', 'age_tier_order', 'days_since_last_update', 'freshness_tier', 'word_count_tier', 'char_count_tier', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier', 'position_tier', 'trend_direction', 'trend_pct']

# %%
df.head()
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %%
df.dtypes
# Out:
# content_id                 object
# client_id                  object
# search_volume             float64
# competition               float64
# competition_level          object
# cpc                       float64
# content_type               object
# main_intent                object
# word_count                float64
# char_count                float64
# provider_used              object
# model_used                 object
# impressions_90d             int64
# clicks_90d                  int64
# pageviews_90d               int64
# sessions_90d                int64
# users_90d                   int64
# engaged_sessions_90d        int64
# ai_sessions_90d             int64
# scroll_events_90d           int64
# days_with_impressions       int64
# days_with_sessions          int64
# impressions_last_30d        int64
# clicks_last_30d             int64
# sessions_last_30d           int64
# impressions_prev_30d        int64
# clicks_prev_30d             int64
# ...

# %%
df.describe(include="all").T
# Out:
#                           count unique                     top   freq  \
# content_id                30000  30000    content_6880eb215048      1
# client_id                 30000     32       client_19581e27de   7008
# search_volume           27532.0    NaN                     NaN    NaN
# competition             27532.0    NaN                     NaN    NaN
# competition_level         27390      3                     LOW  22896
# cpc                     27532.0    NaN                     NaN    NaN
# content_type              30000      3         keyword article  27207
# main_intent               27626      4           informational  17235
# word_count              22301.0    NaN                     NaN    NaN
# char_count              22301.0    NaN                     NaN    NaN
# provider_used              8562      2                  google   7364
# model_used                24267      5  gemini-3-flash-preview  13271
# ...

# %%
df["trend_direction"].value_counts(dropna=False)
# Out:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64

# %%
df["content_age_days"].describe()
# Out:
# count    30000.00000
# mean       256.16780
# std        132.70793
# min         90.00000
# 25%        132.00000
# 50%        236.00000
# 75%        333.00000
# max        564.00000
# Name: content_age_days, dtype: float64

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
